# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

from common_plotting import read_data, plot, years, months, yearsFmt, plot_thp, daysNumberFmt

# %%
thp_data, _ = read_data([])

# %%
thp_data.loc[(datetime.utcnow() - timedelta(days=7)):datetime.utcnow(), 'temperature'].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
thp_data.loc[(datetime.utcnow() - timedelta(days=7)):datetime.utcnow(), 'temperature'].plot()
# Out:
#                             temperature     pressure   humidity
# datetime
# 2022-08-06 23:48:16.890127    34.050781  1028.290722  30.980583
# 2022-08-06 23:48:22.204258    34.052148  1028.279046  31.015336
# 2022-08-06 23:48:27.518716    34.045117  1028.279024  31.032775
# 2022-08-06 23:48:32.836722    34.050781  1028.307446  31.003865
# 2022-08-06 23:48:38.153055    34.042578  1028.265671  30.992264
# ...                                 ...          ...        ...
# 2022-08-09 23:47:50.915387    34.935352  1028.105817  31.308253
# 2022-08-09 23:47:56.233009    34.934570  1028.100797  31.349060
# 2022-08-09 23:48:01.554072    34.933789  1028.115203  31.296719
# 2022-08-09 23:48:06.873131    34.933398  1028.102900  31.441924
# 2022-08-09 23:48:12.187993    34.932422  1028.094122  31.302611
#
# [48728 rows x 3 columns]

# %%
ax = plt.gca()
plot_thp(thp_data.last('7d'), ax);
ax.xaxis.set_major_formatter(daysNumberFmt)
ax.set_xlabel('Day')
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.3,0.1))
